# %%
import tensorflow as tf
import numpy as np
import time
from functools import lru_cache
from typing import List, Tuple
from concurrent.futures import ThreadPoolExecutor


# Directions: up, down, left, right
DIRECTIONS = [(-1, 0), (1, 0), (0, -1), (0, 1)]

# %%
def load_grid(file_path: str) -> np.ndarray:
    """
    Loads grid data from a text file into a 2D NumPy array.

    Parameters:
        file_path (str): Path to the input text file.

    Returns:
        np.ndarray: 2D array representing the grid.
    """
    grid = []
    with open(file_path, 'r') as file:
        for line_number, line in enumerate(file, start=1):
            line = line.strip()
            if not line:
                continue  # Skip empty lines

            try:
                row = [int(char) for char in line]
            except ValueError as e:
                raise ValueError(f"Invalid character in line {line_number}: {e}")
            grid.append(row)
    return np.array(grid)

# %%
data = load_grid("test.txt")
data
# Out:
# array([[0, 1, 2, 3],
#        [1, 2, 3, 4],
#        [8, 7, 6, 5],
#        [9, 8, 7, 6]])

# %%
def find_start_end_positions(grid: np.ndarray) -> Tuple[List[Tuple[int, int]], List[Tuple[int, int]]]:
    """
    Identifies all start (0) and end (9) positions in the grid.

    Parameters:
        grid (np.ndarray): 2D array representing the grid.

    Returns:
        Tuple[List[Tuple[int, int]], List[Tuple[int, int]]]:
            A tuple containing two lists:
                - List of (row, column) tuples for start positions.
                - List of (row, column) tuples for end positions.
    """
    start_positions = list(zip(*np.where(grid == 0)))
    end_positions = list(zip(*np.where(grid == 9)))
    return start_positions, end_positions

# %%
def find_all_trails_parallel(grid: np.ndarray) -> int:
    """
    Finds all valid trails from every 0 to 9 in the grid using parallel processing.

    Parameters:
        grid (np.ndarray): 2D array representing the grid.

    Returns:
        int: Total number of valid trails.
    """
    ROWS, COLS = grid.shape
    DIRECTIONS = [(-1, 0), (1, 0), (0, -1), (0, 1)]  # Up, Down, Left, Right
    start_positions, end_positions = find_start_end_positions(grid)

    print(f"Start positions (0): {start_positions}")
    print(f"End positions (9): {end_positions}\n")

    def dfs(x: int, y: int, current_num: int) -> int:
        """
        Recursively counts the number of paths from (x, y) to any 9,
        where each move increases the number by exactly 1.

        Parameters:
            x (int): Current row.
            y (int): Current column.
            current_num (int): Current number on the grid.

        Returns:
            int: Number of valid paths to 9 from this cell.
        """
        # If current number is 9, we've reached the destination
        if current_num == 9:
            return 1

        total_paths = 0
        next_num = current_num + 1

        # Explore all four directions
        for dx, dy in DIRECTIONS:
            nx, ny = x + dx, y + dy
            # Check boundaries
            if 0 <= nx < ROWS and 0 <= ny < COLS:
                if grid[nx][ny] == next_num:
                    total_paths += dfs(nx, ny, grid[nx][ny])

        return total_paths

    total_trails = 0
    with ThreadPoolExecutor() as executor:
        # Submit DFS tasks for all start positions
        futures = [executor.submit(dfs, x, y, grid[x][y]) for x, y in start_positions]

        # Aggregate the results correctly
        for idx, future in enumerate(futures, start=1):
            trails = future.result()
            print(f"Start {idx}: Position ({start_positions[idx-1][0]}, {start_positions[idx-1][1]}) with {grid[start_positions[idx-1][0], start_positions[idx-1][1]]} → {trails} trail(s)")
            total_trails += trails

    return total_trails

# %%
# Path to your input file
file_path = 'in.txt'  # Ensure this path is correct

# Load the grid
try:
    grid = load_grid(file_path)
 3), (37, 5), (37, 12), (37, 18), (37, 22), (37, 43), (37, 47), (37, 49), (38, 16), (38, 24), (38, 29), (38, 30), (39, 36), (39, 43), (39, 55), (40, 7), (40, 18), (40, 42), (40, 43), (40, 55), (41, 33), (41, 39), (41, 48), (41, 54), (42, 1), (42, 46), (43, 8), (43, 13), (43, 24), (43, 26), (43, 54), (44, 35), (44, 50), (45, 13), (45, 16), (45, 33), (45, 34), (45, 50), (46, 8), (46, 20), (46, 25), (46, 29), (46, 35), (47, 1), (47, 4), (47, 14), (47, 23), (47, 32), (47, 42), (47, 44), (48, 16), (48, 22), (48, 39), (48, 53), (49, 8), (49, 41), (49, 56), (50, 11), (50, 18), (50, 26), (50, 36), (50, 50), (51, 5), (51, 14), (51, 41), (51, 46), (51, 51), (52, 4), (52, 11), (52, 22), (52, 25), (52, 36), (52, 55), (53, 11), (53, 32), (53, 36), (53, 38), (53, 48), (54, 1), (54, 37), (54, 45), (54, 54), (55, 14), (55, 18), (55, 23), (55, 28), (56, 5), (56, 11), (56, 13)]
#
# Start 1: Position (0, 8) with 0 → 7 trail(s)
# Start 2: Position (0, 10) with 0 → 7 trail(s)
# Start 3: Position (0, 11) with 0 → 1 trail(s)
# Start 4: Position (0, 17) with 0 → 6 trail(s)
# Start 5: Position (0, 26) with 0 → 21 trail(s)
# Start 6: Position (0, 28) with 0 → 7 trail(s)
# Start 7: Position (0, 46) with 0 → 4 trail(s)
# Start 8: Position (0, 52) with 0 → 3 trail(s)
# Start 9: Position (0, 56) with 0 → 4 trail(s)
# Start 10: Position (1, 19) with 0 → 2 trail(s)
# Start 11: Position (1, 22) with 0 → 1 trail(s)
# Start 12: Position (1, 25) with 0 → 14 trail(s)
# Start 13: Position (1, 39) with 0 → 2 trail(s)
# Start 14: Position (2, 1) with 0 → 2 trail(s)
# Start 15: Position (2, 11) with 0 → 1 trail(s)
# Start 16: Position (2, 17) with 0 → 3 trail(s)
# Start 17: Position (2, 41) with 0 → 4 trail(s)
# Start 18: Position (2, 52) with 0 → 11 trail(s)
# Start 19: Position (3, 0) with 0 → 4 trail(s)
# Start 20: Position (3, 11) with 0 → 1 trail(s)
# Start 21: Position (3, 15) with 0 → 2 trail(s)
# Start 22: Position (3, 36) with 0 → 2 trail(s)
# Start 23: Position (3, 38) with 0 → 4 trail(s)
# Start 24: Position (3, 47) with 0 → 17 trail(s)
# Start 25: Position (4, 8) with 0 → 1 trail(s)
# Start 26: Position (4, 15) with 0 → 1 trail(s)
# Start 27: Position (4, 22) with 0 → 8 trail(s)
# Start 28: Position (4, 32) with 0 → 17 trail(s)
# Start 29: Position (4, 34) with 0 → 10 trail(s)
# Start 30: Position (4, 46) with 0 → 4 trail(s)
# Start 31: Position (4, 47) with 0 → 6 trail(s)
# Start 32: Position (5, 4) with 0 → 2 trail(s)
# Start 33: Position (5, 11) with 0 → 5 trail(s)
# Start 34: Position (5, 25) with 0 → 4 trail(s)
# Start 35: Position (5, 31) with 0 → 3 trail(s)
# Start 36: Position (5, 38) with 0 → 7 trail(s)
# Start 37: Position (5, 53) with 0 → 8 trail(s)
# Start 38: Position (6, 5) with 0 → 10 trail(s)
# Start 39: Position (6, 17) with 0 → 8 trail(s)
# Start 40: Position (6, 20) with 0 → 1 trail(s)
# Start 41: Position (6, 27) with 0 → 2 trail(s)
# Start 42: Position (6, 43) with 0 → 6 trail(s)
# Start 43: Position (6, 47) with 0 → 13 trail(s)
# Start 44: Position (6, 55) with 0 → 1 trail(s)
# Start 45: Position (7, 6) with 0 → 8 trail(s)
# Start 46: Position (7, 10) with 0 → 2 trail(s)
# Start 47: Position (7, 11) with 0 → 4 trail(s)
# Start 48: Position (7, 21) with 0 → 2 trail(s)
# Start 49: Position (7, 34) with 0 → 12 trail(s)
# Start 50: Position (7, 41) with 0 → 2 trail(s)
# Start 51: Position (7, 48) with 0 → 3 trail(s)
# Start 52: Position (8, 4) with 0 → 3 trail(s)
# Start 53: Position (9, 13) with 0 → 4 trail(s)
# Start 54: Position (9, 29) with 0 → 2 trail(s)
# Start 55: Position (9, 32) with 0 → 6 trail(s)
# Start 56: Position (9, 40) with 0 → 5 trail(s)
# Start 57: Position (10, 6) with 0 → 1 trail(s)
# Start 58: Position (10, 23) with 0 → 2 trail(s)
# Start 59: Position (10, 52) with 0 → 3 trail(s)
# Start 60: Position (11, 1) with 0 → 2 trail(s)
# Start 61: Position (11, 11) with 0 → 4 trail(s)
# Start 62: Position (11, 31) with 0 → 3 trail(s)
# Start 63: Position (11, 32) with 0 → 1 trail(s)
# Start 64: Position (11, 42) with 0 → 2 trail(s)
# Start 65: Position (11, 48) with 0 → 11 trail(s)
# Start 66: Position (11, 51) with 0 → 6 trail(s)
# Start 67: Position (11, 56) with 0 → 1 trail(s)
# Start 68: Position (12, 13) with 0 → 6 trail(s)
# Start 69: Position (12, 17) with 0 → 1 trail(s)
# Start 70: Position (12, 27) with 0 → 5 trail(s)
# Start 71: Position (12, 30) with 0 → 3 trail(s)
# Start 72: Position (13, 35) with 0 → 10 trail(s)
# Start 73: Position (13, 41) with 0 → 3 trail(s)
# Start 74: Position (14, 0) with 0 → 3 trail(s)
# Start 75: Position (14, 5) with 0 → 3 trail(s)
# Start 76: Position (14, 19) with 0 → 1 trail(s)
# Start 77: Position (14, 21) with 0 → 5 trail(s)
# Start 78: Position (14, 24) with 0 → 2 trail(s)
# Start 79: Position (14, 25) with 0 → 2 trail(s)
# Start 80: Position (14, 34) with 0 → 10 trail(s)
# Start 81: Position (14, 39) with 0 → 6 trail(s)
# Start 82: Position (15, 1) with 0 → 1 trail(s)
# Start 83: Position (15, 11) with 0 → 4 trail(s)
# Start 84: Position (15, 19) with 0 → 8 trail(s)
# Start 85: Position (15, 22) with 0 → 4 trail(s)
# Start 86: Position (15, 48) with 0 → 13 trail(s)
# Start 87: Position (16, 1) with 0 → 2 trail(s)
# Start 88: Position (16, 7) with 0 → 6 trail(s)
# Start 89: Position (16, 25) with 0 → 2 trail(s)
# Start 90: Position (16, 26) with 0 → 7 trail(s)
# Start 91: Position (16, 34) with 0 → 8 trail(s)
# Start 92: Position (16, 42) with 0 → 3 trail(s)
# Start 93: Position (16, 47) with 0 → 19 trail(s)
# Start 94: Position (16, 56) with 0 → 5 trail(s)
# Start 95: Position (17, 19) with 0 → 8 trail(s)
# Start 96: Position (17, 41) with 0 → 9 trail(s)
# Start 97: Position (17, 48) with 0 → 2 trail(s)
# Start 98: Position (18, 13) with 0 → 24 trail(s)
# Start 99: Position (18, 26) with 0 → 22 trail(s)
# Start 100: Position (18, 46) with 0 → 1 trail(s)
# Start 101: Position (18, 52) with 0 → 1 trail(s)
# Start 102: Position (18, 55) with 0 → 1 trail(s)
# Start 103: Position (19, 3) with 0 → 3 trail(s)
# Start 104: Position (19, 23) with 0 → 3 trail(s)
# Start 105: Position (19, 34) with 0 → 4 trail(s)
# Start 106: Position (19, 35) with 0 → 4 trail(s)
# Start 107: Position (19, 40) with 0 → 4 trail(s)
# Start 108: Position (19, 48) with 0 → 3 trail(s)
# Start 109: Position (19, 55) with 0 → 5 trail(s)
# Start 110: Position (20, 15) with 0 → 18 trail(s)
# Start 111: Position (20, 21) with 0 → 5 trail(s)
# Start 112: Position (20, 24) with 0 → 3 trail(s)
# Start 113: Position (20, 32) with 0 → 3 trail(s)
# Start 114: Position (20, 50) with 0 → 2 trail(s)
# Start 115: Position (21, 1) with 0 → 10 trail(s)
# Start 116: Position (21, 8) with 0 → 1 trail(s)
# Start 117: Position (21, 10) with 0 → 12 trail(s)
# Start 118: Position (21, 22) with 0 → 5 trail(s)
# Start 119: Position (21, 30) with 0 → 3 trail(s)
# Start 120: Position (21, 40) with 0 → 4 trail(s)
# Start 121: Position (21, 43) with 0 → 2 trail(s)
# Start 122: Position (21, 51) with 0 → 4 trail(s)
# Start 123: Position (22, 0) with 0 → 3 trail(s)
# Start 124: Position (22, 4) with 0 → 5 trail(s)
# Start 125: Position (22, 11) with 0 → 18 trail(s)
# Start 126: Position (22, 20) with 0 → 6 trail(s)
# Start 127: Position (22, 52) with 0 → 4 trail(s)
# Start 128: Position (23, 10) with 0 → 6 trail(s)
# Start 129: Position (23, 14) with 0 → 3 trail(s)
# Start 130: Position (23, 16) with 0 → 7 trail(s)
# Start 131: Position (23, 28) with 0 → 3 trail(s)
# Start 132: Position (24, 4) with 0 → 7 trail(s)
# Start 133: Position (24, 22) with 0 → 2 trail(s)
# Start 134: Position (24, 30) with 0 → 1 trail(s)
# Start 135: Position (24, 51) with 0 → 6 trail(s)
# Start 136: Position (25, 9) with 0 → 1 trail(s)
# Start 137: Position (25, 23) with 0 → 6 trail(s)
# Start 138: Position (25, 27) with 0 → 2 trail(s)
# Start 139: Position (25, 35) with 0 → 1 trail(s)
# Start 140: Position (25, 38) with 0 → 9 trail(s)
# Start 141: Position (25, 40) with 0 → 2 trail(s)
# Start 142: Position (25, 43) with 0 → 1 trail(s)
# Start 143: Position (25, 49) with 0 → 4 trail(s)
# Start 144: Position (26, 9) with 0 → 2 trail(s)
# Start 145: Position (26, 17) with 0 → 2 trail(s)
# Start 146: Position (26, 34) with 0 → 4 trail(s)
# Start 147: Position (26, 39) with 0 → 7 trail(s)
# Start 148: Position (26, 41) with 0 → 2 trail(s)
# Start 149: Position (27, 5) with 0 → 10 trail(s)
# Start 150: Position (27, 10) with 0 → 2 trail(s)
# Start 151: Position (27, 17) with 0 → 1 trail(s)
# Start 152: Position (27, 54) with 0 → 3 trail(s)
# Start 153: Position (28, 0) with 0 → 6 trail(s)
# Start 154: Position (28, 1) with 0 → 1 trail(s)
# Start 155: Position (28, 5) with 0 → 1 trail(s)
# Start 156: Position (28, 18) with 0 → 2 trail(s)
# Start 157: Position (28, 23) with 0 → 2 trail(s)
# Start 158: Position (28, 31) with 0 → 9 trail(s)
# Start 159: Position (28, 37) with 0 → 5 trail(s)
# Start 160: Position (29, 3) with 0 → 4 trail(s)
# Start 161: Position (29, 16) with 0 → 4 trail(s)
# Start 162: Position (29, 30) with 0 → 9 trail(s)
# Start 163: Position (29, 45) with 0 → 1 trail(s)
# Start 164: Position (29, 51) with 0 → 3 trail(s)
# Start 165: Position (30, 22) with 0 → 2 trail(s)
# Start 166: Position (30, 27) with 0 → 6 trail(s)
# Start 167: Position (30, 34) with 0 → 2 trail(s)
# Start 168: Position (30, 37) with 0 → 9 trail(s)
# Start 169: Position (30, 43) with 0 → 2 trail(s)
# Start 170: Position (30, 47) with 0 → 2 trail(s)
# Start 171: Position (30, 51) with 0 → 3 trail(s)
# Start 172: Position (30, 52) with 0 → 6 trail(s)
# Start 173: Position (31, 9) with 0 → 13 trail(s)
# Start 174: Position (31, 21) with 0 → 2 trail(s)
# Start 175: Position (31, 29) with 0 → 1 trail(s)
# Start 176: Position (31, 31) with 0 → 1 trail(s)
# Start 177: Position (31, 34) with 0 → 2 trail(s)
# Start 178: Position (32, 0) with 0 → 2 trail(s)
# Start 179: Position (32, 8) with 0 → 13 trail(s)
# Start 180: Position (32, 13) with 0 → 5 trail(s)
# Start 181: Position (32, 19) with 0 → 1 trail(s)
# Start 182: Position (32, 52) with 0 → 6 trail(s)
# Start 183: Position (32, 55) with 0 → 4 trail(s)
# Start 184: Position (33, 14) with 0 → 5 trail(s)
# Start 185: Position (33, 15) with 0 → 4 trail(s)
# Start 186: Position (33, 26) with 0 → 6 trail(s)
# Start 187: Position (33, 28) with 0 → 2 trail(s)
# Start 188: Position (33, 36) with 0 → 2 trail(s)
# Start 189: Position (33, 43) with 0 → 1 trail(s)
# Start 190: Position (33, 50) with 0 → 3 trail(s)
# Start 191: Position (34, 1) with 0 → 4 trail(s)
# Start 192: Position (34, 3) with 0 → 5 trail(s)
# Start 193: Position (34, 8) with 0 → 19 trail(s)
# Start 194: Position (34, 14) with 0 → 7 trail(s)
# Start 195: Position (34, 18) with 0 → 3 trail(s)
# Start 196: Position (34, 27) with 0 → 4 trail(s)
# Start 197: Position (34, 43) with 0 → 14 trail(s)
# Start 198: Position (34, 49) with 0 → 10 trail(s)
# Start 199: Position (34, 56) with 0 → 2 trail(s)
# Start 200: Position (35, 30) with 0 → 2 trail(s)
# Start 201: Position (35, 39) with 0 → 4 trail(s)
# Start 202: Position (35, 48) with 0 → 27 trail(s)
# Start 203: Position (36, 33) with 0 → 6 trail(s)
# Start 204: Position (36, 51) with 0 → 3 trail(s)
# Start 205: Position (36, 54) with 0 → 4 trail(s)
# Start 206: Position (37, 4) with 0 → 5 trail(s)
# Start 207: Position (37, 19) with 0 → 1 trail(s)
# Start 208: Position (37, 20) with 0 → 1 trail(s)
# Start 209: Position (37, 44) with 0 → 14 trail(s)
# Start 210: Position (38, 7) with 0 → 1 trail(s)
# Start 211: Position (38, 8) with 0 → 14 trail(s)
# Start 212: Position (38, 12) with 0 → 1 trail(s)
# Start 213: Position (38, 15) with 0 → 1 trail(s)
# Start 214: Position (38, 25) with 0 → 1 trail(s)
# Start 215: Position (38, 40) with 0 → 3 trail(s)
# Start 216: Position (38, 55) with 0 → 1 trail(s)
# Start 217: Position (39, 11) with 0 → 9 trail(s)
# Start 218: Position (39, 35) with 0 → 2 trail(s)
# Start 219: Position (39, 46) with 0 → 4 trail(s)
# Start 220: Position (39, 51) with 0 → 7 trail(s)
# Start 221: Position (40, 8) with 0 → 7 trail(s)
# Start 222: Position (40, 21) with 0 → 4 trail(s)
# Start 223: Position (40, 24) with 0 → 12 trail(s)
# Start 224: Position (40, 26) with 0 → 4 trail(s)
# Start 225: Position (40, 29) with 0 → 21 trail(s)
# Start 226: Position (40, 31) with 0 → 11 trail(s)
# Start 227: Position (41, 1) with 0 → 2 trail(s)
# Start 228: Position (41, 3) with 0 → 2 trail(s)
# Start 229: Position (41, 6) with 0 → 3 trail(s)
# Start 230: Position (41, 11) with 0 → 16 trail(s)
# Start 231: Position (41, 40) with 0 → 2 trail(s)
# Start 232: Position (41, 43) with 0 → 1 trail(s)
# Start 233: Position (41, 46) with 0 → 2 trail(s)
# Start 234: Position (42, 4) with 0 → 6 trail(s)
# Start 235: Position (42, 22) with 0 → 8 trail(s)
# Start 236: Position (42, 35) with 0 → 2 trail(s)
# Start 237: Position (42, 38) with 0 → 17 trail(s)
# Start 238: Position (43, 0) with 0 → 1 trail(s)
# Start 239: Position (43, 3) with 0 → 6 trail(s)
# Start 240: Position (43, 6) with 0 → 2 trail(s)
# Start 241: Position (43, 12) with 0 → 2 trail(s)
# Start 242: Position (43, 15) with 0 → 1 trail(s)
# Start 243: Position (43, 20) with 0 → 5 trail(s)
# Start 244: Position (43, 30) with 0 → 3 trail(s)
# Start 245: Position (43, 36) with 0 → 4 trail(s)
# Start 246: Position (43, 38) with 0 → 2 trail(s)
# Start 247: Position (43, 40) with 0 → 1 trail(s)
# Start 248: Position (43, 45) with 0 → 2 trail(s)
# Start 249: Position (44, 21) with 0 → 3 trail(s)
# Start 250: Position (44, 30) with 0 → 10 trail(s)
# Start 251: Position (44, 32) with 0 → 1 trail(s)
# Start 252: Position (44, 56) with 0 → 8 trail(s)
# Start 253: Position (45, 24) with 0 → 3 trail(s)
# Start 254: Position (45, 48) with 0 → 4 trail(s)
# Start 255: Position (45, 51) with 0 → 2 trail(s)
# Start 256: Position (45, 52) with 0 → 1 trail(s)
# Start 257: Position (46, 11) with 0 → 2 trail(s)
# Start 258: Position (46, 12) with 0 → 3 trail(s)
# Start 259: Position (46, 13) with 0 → 1 trail(s)
# Start 260: Position (46, 14) with 0 → 1 trail(s)
# Start 261: Position (46, 18) with 0 → 2 trail(s)
# Start 262: Position (46, 28) with 0 → 8 trail(s)
# Start 263: Position (46, 34) with 0 → 8 trail(s)
# Start 264: Position (47, 10) with 0 → 5 trail(s)
# Start 265: Position (47, 11) with 0 → 3 trail(s)
# Start 266: Position (47, 25) with 0 → 8 trail(s)
# Start 267: Position (47, 37) with 0 → 34 trail(s)
# Start 268: Position (48, 38) with 0 → 17 trail(s)
# Start 269: Position (48, 42) with 0 → 2 trail(s)
# Start 270: Position (48, 56) with 0 → 6 trail(s)
# Start 271: Position (49, 6) with 0 → 7 trail(s)
# Start 272: Position (49, 18) with 0 → 4 trail(s)
# Start 273: Position (49, 31) with 0 → 4 trail(s)
# Start 274: Position (49, 45) with 0 → 2 trail(s)
# Start 275: Position (49, 51) with 0 → 1 trail(s)
# Start 276: Position (49, 53) with 0 → 5 trail(s)
# Start 277: Position (50, 3) with 0 → 5 trail(s)
# Start 278: Position (50, 5) with 0 → 10 trail(s)
# Start 279: Position (50, 9) with 0 → 7 trail(s)
# Start 280: Position (50, 23) with 0 → 6 trail(s)
# Start 281: Position (50, 25) with 0 → 6 trail(s)
# Start 282: Position (50, 30) with 0 → 6 trail(s)
# Start 283: Position (50, 34) with 0 → 26 trail(s)
# Start 284: Position (50, 44) with 0 → 7 trail(s)
# Start 285: Position (50, 47) with 0 → 1 trail(s)
# Start 286: Position (51, 8) with 0 → 7 trail(s)
# Start 287: Position (51, 17) with 0 → 6 trail(s)
# Start 288: Position (51, 20) with 0 → 13 trail(s)
# Start 289: Position (51, 31) with 0 → 7 trail(s)
# Start 290: Position (51, 34) with 0 → 2 trail(s)
# Start 291: Position (51, 50) with 0 → 1 trail(s)
# Start 292: Position (52, 1) with 0 → 9 trail(s)
# Start 293: Position (52, 15) with 0 → 1 trail(s)
# Start 294: Position (52, 28) with 0 → 4 trail(s)
# Start 295: Position (52, 30) with 0 → 9 trail(s)
# Start 296: Position (52, 39) with 0 → 2 trail(s)
# Start 297: Position (52, 40) with 0 → 6 trail(s)
# Start 298: Position (52, 46) with 0 → 2 trail(s)
# Start 299: Position (52, 52) with 0 → 2 trail(s)
# Start 300: Position (53, 24) with 0 → 2 trail(s)
# Start 301: Position (54, 6) with 0 → 4 trail(s)
# Start 302: Position (54, 10) with 0 → 6 trail(s)
# Start 303: Position (54, 30) with 0 → 2 trail(s)
# Start 304: Position (54, 36) with 0 → 4 trail(s)
# Start 305: Position (54, 56) with 0 → 1 trail(s)
# Start 306: Position (55, 5) with 0 → 4 trail(s)
# Start 307: Position (55, 19) with 0 → 1 trail(s)
# Start 308: Position (55, 34) with 0 → 2 trail(s)
# Start 309: Position (55, 40) with 0 → 6 trail(s)
# Start 310: Position (55, 52) with 0 → 2 trail(s)
# Start 311: Position (56, 6) with 0 → 4 trail(s)
# Start 312: Position (56, 10) with 0 → 4 trail(s)
# Start 313: Position (56, 16) with 0 → 2 trail(s)
# Start 314: Position (56, 19) with 0 → 1 trail(s)
# Start 315: Position (56, 25) with 0 → 2 trail(s)
# Start 316: Position (56, 34) with 0 → 4 trail(s)
# Start 317: Position (56, 44) with 0 → 2 trail(s)
# Start 318: Position (56, 48) with 0 → 2 trail(s)
# ---------------------------------------------------
# Sum of all possible trails: 1609
